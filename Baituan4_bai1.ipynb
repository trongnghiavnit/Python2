# %%
import numpy as np

import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.609597  0.661763 -0.040501  0.138694
# 2013-01-02  2.871850 -0.466885  0.257460  1.098423
# 2013-01-03 -0.746110  0.554140  0.100216 -0.024887
# 2013-01-04 -1.366285 -0.467750 -0.074929  0.019399
# 2013-01-05  0.235266 -1.229058 -0.873417  1.109417
# 2013-01-06 -1.698409 -1.111432  0.731368  0.270146

# %%
df2 = pd.DataFrame({'A': 1.,
'B': pd.Timestamp('20130102'),
'C': pd.Series(1, index=list(range(4)), dtype='float32'),
'D': np.array([3] * 4, dtype='int32'),
'E': pd.Categorical(["test", "train", "test", "train"]),
'F': 'foo'})

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.abs
# Out:
# <bound method NDFrame.abs of      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo>

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -0.609597  0.661763 -0.040501  0.138694
# 2013-01-02  2.871850 -0.466885  0.257460  1.098423
# 2013-01-03 -0.746110  0.554140  0.100216 -0.024887
# 2013-01-04 -1.366285 -0.467750 -0.074929  0.019399
# 2013-01-05  0.235266 -1.229058 -0.873417  1.109417

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04 -1.366285 -0.467750 -0.074929  0.019399
# 2013-01-05  0.235266 -1.229058 -0.873417  1.109417
# 2013-01-06 -1.698409 -1.111432  0.731368  0.270146

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[-0.60959734,  0.66176347, -0.0405014 ,  0.13869361],
#        [ 2.87185048, -0.46688497,  0.25746015,  1.09842317],
#        [-0.74610987,  0.55413986,  0.10021575, -0.02488672],
#        [-1.36628541, -0.46774953, -0.07492868,  0.01939911],
#        [ 0.23526613, -1.22905758, -0.87341674,  1.10941676],
#        [-1.69840917, -1.11143202,  0.73136766,  0.27014561]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.218881 -0.343203  0.016699  0.435199
# std    1.654995  0.802609  0.525293  0.528046
# min   -1.698409 -1.229058 -0.873417 -0.024887
# 25%   -1.211242 -0.950511 -0.066322  0.049223
# 50%   -0.677854 -0.467317  0.029857  0.204420
# 75%    0.024050  0.298884  0.218149  0.891354
# max    2.871850  0.661763  0.731368  1.109417

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -0.609597    2.871850   -0.746110   -1.366285    0.235266   -1.698409
# B    0.661763   -0.466885    0.554140   -0.467750   -1.229058   -1.111432
# C   -0.040501    0.257460    0.100216   -0.074929   -0.873417    0.731368
# D    0.138694    1.098423   -0.024887    0.019399    1.109417    0.270146

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.138694 -0.040501  0.661763 -0.609597
# 2013-01-02  1.098423  0.257460 -0.466885  2.871850
# 2013-01-03 -0.024887  0.100216  0.554140 -0.746110
# 2013-01-04  0.019399 -0.074929 -0.467750 -1.366285
# 2013-01-05  1.109417 -0.873417 -1.229058  0.235266
# 2013-01-06  0.270146  0.731368 -1.111432 -1.698409

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2013-01-05  0.235266 -1.229058 -0.873417  1.109417
# 2013-01-06 -1.698409 -1.111432  0.731368  0.270146
# 2013-01-04 -1.366285 -0.467750 -0.074929  0.019399
# 2013-01-02  2.871850 -0.466885  0.257460  1.098423
# 2013-01-03 -0.746110  0.554140  0.100216 -0.024887
# 2013-01-01 -0.609597  0.661763 -0.040501  0.138694

# %%
df['A']
# Out:
# 2013-01-01   -0.609597
# 2013-01-02    2.871850
# 2013-01-03   -0.746110
# 2013-01-04   -1.366285
# 2013-01-05    0.235266
# 2013-01-06   -1.698409
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -0.609597  0.661763 -0.040501  0.138694
# 2013-01-02  2.871850 -0.466885  0.257460  1.098423
# 2013-01-03 -0.746110  0.554140  0.100216 -0.024887

# %%
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02  2.871850 -0.466885  0.257460  1.098423
# 2013-01-03 -0.746110  0.554140  0.100216 -0.024887
# 2013-01-04 -1.366285 -0.467750 -0.074929  0.019399

# %%
df.loc[dates[0]]
# Out:
# A   -0.609597
# B    0.661763
# C   -0.040501
# D    0.138694
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2013-01-01 -0.609597  0.661763
# 2013-01-02  2.871850 -0.466885
# 2013-01-03 -0.746110  0.554140
# 2013-01-04 -1.366285 -0.467750
# 2013-01-05  0.235266 -1.229058
# 2013-01-06 -1.698409 -1.111432

# %%
df.loc['20130102':'20130104', ['A', 'B']]
# Out:
#                    A         B
# 2013-01-02  2.871850 -0.466885
# 2013-01-03 -0.746110  0.554140
# 2013-01-04 -1.366285 -0.467750

# %%
df.loc['20130102', ['A', 'B']]
# Out:
# A    2.871850
# B   -0.466885
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.loc[dates[0], 'A']
# Out:
# -0.6095973350668434

# %%
df.at[dates[0], 'A']
# Out:
# -0.6095973350668434

# %%
df.iloc[3]
# Out:
# A   -1.366285
# B   -0.467750
# C   -0.074929
# D    0.019399
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04 -1.366285 -0.467750
# 2013-01-05  0.235266 -1.229058

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02  2.871850  0.257460
# 2013-01-03 -0.746110  0.100216
# 2013-01-05  0.235266 -0.873417

# %%
In [35]: df.iloc[1:3, :]
# Out:
#                   A         B         C         D
# 2013-01-02  2.87185 -0.466885  0.257460  1.098423
# 2013-01-03 -0.74611  0.554140  0.100216 -0.024887

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01  0.661763 -0.040501
# 2013-01-02 -0.466885  0.257460
# 2013-01-03  0.554140  0.100216
# 2013-01-04 -0.467750 -0.074929
# 2013-01-05 -1.229058 -0.873417
# 2013-01-06 -1.111432  0.731368

# %%
df.iloc[1, 1]
# Out:
# -0.46688496719956446

# %%
df.iat[1, 1]
# Out:
# -0.46688496719956446

# %%
df[df['A'] > 0]
# Out:
#                    A         B         C         D
# 2013-01-02  2.871850 -0.466885  0.257460  1.098423
# 2013-01-05  0.235266 -1.229058 -0.873417  1.109417

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN  0.661763       NaN  0.138694
# 2013-01-02  2.871850       NaN  0.257460  1.098423
# 2013-01-03       NaN  0.554140  0.100216       NaN
# 2013-01-04       NaN       NaN       NaN  0.019399
# 2013-01-05  0.235266       NaN       NaN  1.109417
# 2013-01-06       NaN       NaN  0.731368  0.270146

# %%
df2 = df.copy()

# %%
df2['E'] = ['one', 'one', 'two', 'three', 'four', 'three']

# %%
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -0.609597  0.661763 -0.040501  0.138694    one
# 2013-01-02  2.871850 -0.466885  0.257460  1.098423    one
# 2013-01-03 -0.746110  0.554140  0.100216 -0.024887    two
# 2013-01-04 -1.366285 -0.467750 -0.074929  0.019399  three
# 2013-01-05  0.235266 -1.229058 -0.873417  1.109417   four
# 2013-01-06 -1.698409 -1.111432  0.731368  0.270146  three

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range('20130102', periods=6))

# %%
df['F'] = s1

# %%
df.at[dates[0], 'A'] = 0

# %%
df.iat[0, 1] = 0

# %%
df.loc[:, 'D'] = np.array([5] * len(df))

# %%
df2 = df.copy()

# %%
df2[df2 > 0] = -df2

# %%
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -0.040501 -5  NaN
# 2013-01-02 -2.871850 -0.466885 -0.257460 -5 -1.0
# 2013-01-03 -0.746110 -0.554140 -0.100216 -5 -2.0
# 2013-01-04 -1.366285 -0.467750 -0.074929 -5 -3.0
# 2013-01-05 -0.235266 -1.229058 -0.873417 -5 -4.0
# 2013-01-06 -1.698409 -1.111432 -0.731368 -5 -5.0

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])

# %%
df1.loc[dates[0]:dates[1], 'E'] = 1

# %%
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -0.040501  5  NaN  1.0
# 2013-01-02  2.871850 -0.466885  0.257460  5  1.0  1.0
# 2013-01-03 -0.746110  0.554140  0.100216  5  2.0  NaN
# 2013-01-04 -1.366285 -0.467750 -0.074929  5  3.0  NaN

# %%
df1.dropna(how='any')
# Out:
#                   A         B        C  D    F    E
# 2013-01-02  2.87185 -0.466885  0.25746  5  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -0.040501  5  5.0  1.0
# 2013-01-02  2.871850 -0.466885  0.257460  5  1.0  1.0
# 2013-01-03 -0.746110  0.554140  0.100216  5  2.0  5.0
# 2013-01-04 -1.366285 -0.467750 -0.074929  5  3.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
df.mean()
# Out:
# A   -0.117281
# B   -0.453497
# C    0.016699
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2013-01-01    1.239875
# 2013-01-02    1.732485
# 2013-01-03    1.381649
# 2013-01-04    1.218207
# 2013-01-05    1.426558
# 2013-01-06    1.584305
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)

# %%
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis='index')
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -1.746110 -0.445860 -0.899784  4.0  1.0
# 2013-01-04 -4.366285 -3.467750 -3.074929  2.0  0.0
# 2013-01-05 -4.764734 -6.229058 -5.873417  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.000000  0.000000 -0.040501   5   NaN
# 2013-01-02  2.871850 -0.466885  0.216959  10   1.0
# 2013-01-03  2.125741  0.087255  0.317174  15   3.0
# 2013-01-04  0.759455 -0.380495  0.242246  20   6.0
# 2013-01-05  0.994721 -1.609552 -0.631171  25  10.0
# 2013-01-06 -0.703688 -2.720984  0.100197  30  15.0

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    4.570260
# B    1.783197
# C    1.604784
# D    0.000000
# F    4.000000
# dtype: float64

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s
# Out:
# 0    5
# 1    3
# 2    1
# 3    5
# 4    3
# 5    0
# 6    0
# 7    4
# 8    3
# 9    1
# dtype: int64

# %%
s.value_counts()
# Out:
# 3    3
# 5    2
# 1    2
# 0    2
# 4    1
# dtype: int64

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))

# %%
df
# Out:
#           0         1         2         3
# 0  0.144480 -0.721720  0.609671 -0.187761
# 1 -0.294534  0.538643  1.419054  0.320150
# 2  0.358443  1.256913 -1.042869  0.731060
# 3  0.663820 -1.532922  0.115063 -0.847122
# 4 -0.312153  0.558524  1.095739 -0.882474
# 5  1.017572  1.143108  0.423652 -0.300073
# 6 -2.871844 -0.509671 -1.355948  0.696021
# 7  0.946091  0.390993 -1.271685 -1.158882
# 8 -1.501196 -1.488621  0.838890  0.040709
# 9 -0.055233  0.707001 -0.849692  0.865741

# %%
pieces = [df[:3], df[3:7], df[7:]]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.144480 -0.721720  0.609671 -0.187761
# 1 -0.294534  0.538643  1.419054  0.320150
# 2  0.358443  1.256913 -1.042869  0.731060
# 3  0.663820 -1.532922  0.115063 -0.847122
# 4 -0.312153  0.558524  1.095739 -0.882474
# 5  1.017572  1.143108  0.423652 -0.300073
# 6 -2.871844 -0.509671 -1.355948  0.696021
# 7  0.946091  0.390993 -1.271685 -1.158882
# 8 -1.501196 -1.488621  0.838890  0.040709
# 9 -0.055233  0.707001 -0.849692  0.865741

# %%
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})

# %%
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
                           'foo', 'bar', 'foo', 'foo'],
                      'B': ['one', 'one', 'two', 'three',
                             'two', 'two', 'one', 'three'],
                       'C': np.random.randn(8),
                     'D': np.random.randn(8)})

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one  0.207418 -1.316908
# 1  bar    one  1.153317  0.403398
# 2  foo    two  0.974381 -2.541485
# 3  bar  three  0.849171  0.510334
# 4  foo    two  1.155977  1.114321
# 5  bar    two  1.714695  0.803717
# 6  foo    one -0.676033 -0.561014
# 7  foo  three -1.288487 -0.505597

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  3.717182  1.717450
# foo  0.373257 -3.810684

# %%
df.groupby(['A', 'B']).sum()
# Out:
#                   C         D
# A   B
# bar one    1.153317  0.403398
#     three  0.849171  0.510334
#     two    1.714695  0.803717
# foo one   -0.468614 -1.877922
#     three -1.288487 -0.505597
#     two    2.130358 -1.427165

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
                       'foo', 'foo', 'qux', 'qux'],
                        ['one', 'two', 'one', 'two',
                        'one', 'two', 'one', 'two']]))

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one     0.601896  0.661135
#       two    -0.497499  0.763097
# baz   one     1.739380  0.248315
#       two    -0.666017 -0.547706

# %%
stacked = df2.stack()

# %%
stacked
# Out:
# first  second
# bar    one     A    0.601896
#                B    0.661135
#        two     A   -0.497499
#                B    0.763097
# baz    one     A    1.739380
#                B    0.248315
#        two     A   -0.666017
#                B   -0.547706
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     0.601896  0.661135
#       two    -0.497499  0.763097
# baz   one     1.739380  0.248315
#       two    -0.666017 -0.547706

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  0.601896 -0.497499
#       B  0.661135  0.763097
# baz   A  1.739380 -0.666017
#       B  0.248315 -0.547706

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A  0.601896  1.739380
#        B  0.661135  0.248315
# two    A -0.497499 -0.666017
#        B  0.763097 -0.547706

# %%
 df = pd.DataFrame({'A': ['one', 'one', 'two', 'three'] * 3,
                       'B': ['A', 'B', 'C'] * 4,
                       'C': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                       'D': np.random.randn(12),
                      'E': np.random.randn(12)})

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.130642  0.089132
# 1     one  B  foo -0.115087  0.145555
# 2     two  C  foo  0.206493 -1.626715
# 3   three  A  bar  1.115485 -0.740001
# 4     one  B  bar -0.677142  1.009949
# 5     one  C  bar  0.048401  2.007675
# 6     two  A  foo -0.101706 -0.688172
# 7   three  B  foo -0.090737 -0.763228
# 8     one  C  foo  0.156701  0.698528
# 9     one  A  bar -2.065686 -0.589819
# 10    two  B  bar  0.237571 -0.132232
# 11  three  C  bar -1.098233  1.401553

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A -2.065686 -0.130642
#       B -0.677142 -0.115087
#       C  0.048401  0.156701
# three A  1.115485       NaN
#       B       NaN -0.090737
#       C -1.098233       NaN
# two   A       NaN -0.101706
#       B  0.237571       NaN
#       C       NaN  0.206493

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='S')

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts.resample('5Min').sum()
# Out:
# 2012-01-01    25967
# Freq: 5T, dtype: int64

# %%
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts
# Out:
# 2012-03-06   -0.056884
# 2012-03-07   -1.017941
# 2012-03-08    0.271215
# 2012-03-09   -0.619470
# 2012-03-10   -0.755900
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')

# %%
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -0.056884
# 2012-03-07 00:00:00+00:00   -1.017941
# 2012-03-08 00:00:00+00:00    0.271215
# 2012-03-09 00:00:00+00:00   -0.619470
# 2012-03-10 00:00:00+00:00   -0.755900
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00   -0.056884
# 2012-03-06 19:00:00-05:00   -1.017941
# 2012-03-07 19:00:00-05:00    0.271215
# 2012-03-08 19:00:00-05:00   -0.619470
# 2012-03-09 19:00:00-05:00   -0.755900
# Freq: D, dtype: float64

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')

# %%
ts = pd.Series(np.random.randn(len(rng)), index=rng)

# %%
ts
# Out:
# 2012-01-31    0.499446
# 2012-02-29    0.814084
# 2012-03-31   -0.308190
# 2012-04-30    0.088041
# 2012-05-31   -0.627331
# Freq: M, dtype: float64

# %%
 ps = ts.to_period()

# %%
ps
# Out:
# 2012-01    0.499446
# 2012-02    0.814084
# 2012-03   -0.308190
# 2012-04    0.088041
# 2012-05   -0.627331
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01    0.499446
# 2012-02-01    0.814084
# 2012-03-01   -0.308190
# 2012-04-01    0.088041
# 2012-05-01   -0.627331
# Freq: MS, dtype: float64

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')

# %%
ts = pd.Series(np.random.randn(len(prng)), prng)

# %%
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9

# %%
ts.head()
# Out:
# 1990-03-01 09:00   -0.385837
# 1990-06-01 09:00   -0.430605
# 1990-09-01 09:00   -2.317008
# 1990-12-01 09:00    0.913387
# 1991-03-01 09:00    1.035709
# Freq: H, dtype: float64

# %%
In [123]: df = pd.DataFrame({"id": [1, 2, 3, 4, 5, 6],
                       "raw_grade": ['a', 'b', 'b', 'a', 'a', 'e']})

# %%
df["grade"] = df["raw_grade"].astype("category")

# %%
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium",
                                                  "good", "very good"])

# %%
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade").size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.close('all')

# %%
ts = pd.Series(np.random.randn(1000),
                  index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
                   columns=['A', 'B', 'C', 'D'])

# %%
df = df.cumsum()

# %%
plt.figure()

# %%
df.plot()

# %%
plt.legend(loc='best')
# Out:
# No handles with labels found to put in legend.

# %%
df.to_csv('foo.csv')

# %%
pd.read_csv('foo.csv')
# Out:
#      Unnamed: 0          A          B          C          D
# 0    2000-01-01  -1.079905  -0.354195  -1.243035   0.792192
# 1    2000-01-02   0.162530  -1.326778  -2.167489   0.859583
# 2    2000-01-03   0.438213  -1.025483  -3.973158   0.194205
# 3    2000-01-04   0.721789  -2.150167  -4.855801   1.339520
# 4    2000-01-05   1.410846  -0.429405  -4.392360   1.663312
# ..          ...        ...        ...        ...        ...
# 995  2002-09-22 -37.609024 -45.452498 -94.769816  21.124468
# 996  2002-09-23 -38.948174 -47.490389 -93.615771  21.543854
# 997  2002-09-24 -40.033642 -48.045435 -92.869194  19.535521
# 998  2002-09-25 -40.226852 -47.993091 -94.291627  19.094476
# 999  2002-09-26 -39.111348 -48.749315 -95.454551  19.786299
#
# [1000 rows x 5 columns]

# %%
df.to_hdf('foo.h5', 'df')

# %%
pd.read_hdf('foo.h5', 'df')
# Out:
#                     A          B          C          D
# 2000-01-01  -1.079905  -0.354195  -1.243035   0.792192
# 2000-01-02   0.162530  -1.326778  -2.167489   0.859583
# 2000-01-03   0.438213  -1.025483  -3.973158   0.194205
# 2000-01-04   0.721789  -2.150167  -4.855801   1.339520
# 2000-01-05   1.410846  -0.429405  -4.392360   1.663312
# ...               ...        ...        ...        ...
# 2002-09-22 -37.609024 -45.452498 -94.769816  21.124468
# 2002-09-23 -38.948174 -47.490389 -93.615771  21.543854
# 2002-09-24 -40.033642 -48.045435 -92.869194  19.535521
# 2002-09-25 -40.226852 -47.993091 -94.291627  19.094476
# 2002-09-26 -39.111348 -48.749315 -95.454551  19.786299
#
# [1000 rows x 4 columns]

# %%
df.to_excel('foo.xlsx', sheet_name='Sheet1')

# %%
pd.read_excel('foo.xlsx', 'Sheet1', index_col=None, na_values=['NA'])
# Out:
#     Unnamed: 0          A          B          C          D
# 0   2000-01-01  -1.079905  -0.354195  -1.243035   0.792192
# 1   2000-01-02   0.162530  -1.326778  -2.167489   0.859583
# 2   2000-01-03   0.438213  -1.025483  -3.973158   0.194205
# 3   2000-01-04   0.721789  -2.150167  -4.855801   1.339520
# 4   2000-01-05   1.410846  -0.429405  -4.392360   1.663312
# ..         ...        ...        ...        ...        ...
# 995 2002-09-22 -37.609024 -45.452498 -94.769816  21.124468
# 996 2002-09-23 -38.948174 -47.490389 -93.615771  21.543854
# 997 2002-09-24 -40.033642 -48.045435 -92.869194  19.535521
# 998 2002-09-25 -40.226852 -47.993091 -94.291627  19.094476
# 999 2002-09-26 -39.111348 -48.749315 -95.454551  19.786299
#
# [1000 rows x 5 columns]
