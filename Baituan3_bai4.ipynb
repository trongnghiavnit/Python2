# %%
import math
import statistics
import numpy as np
import scipy.stats
import pandas as pd

# %%
x = [8.0, 1, 2.5, 4, 28.0]
x_with_nan = [8.0, 1, 2.5, math.nan, 4, 28.0]
x

x_with_nan
# Out:
# [8.0, 1, 2.5, nan, 4, 28.0]

# %%
y, y_with_nan = np.array(x), np.array(x_with_nan)
z, z_with_nan = pd.Series(x), pd.Series(x_with_nan)
y

y_with_nan

z






z_with_nan
# Out:
# 0     8.0
# 1     1.0
# 2     2.5
# 3     NaN
# 4     4.0
# 5    28.0
# dtype: float64

# %%
mean_ = sum(x) / len(x)
mean_
# Out:
# 8.7

# %%
mean_ = statistics.mean(x)
mean_
# Out:
# 8.7

# %%
mean_ = statistics.mean(x_with_nan)
mean_
# Out:
# nan

# %%
mean_ = np.mean(y)
mean_
# Out:
# 8.7

# %%
mean_ = y.mean()
mean_
# Out:
# 8.7

# %%
np.mean(y_with_nan)

y_with_nan.mean()
# Out:
# nan

# %%
np.nanmean(y_with_nan)
# Out:
# 8.7

# %%
mean_ = z.mean()
mean_
# Out:
# 8.7

# %%
z_with_nan.mean()
# Out:
# 8.7

# %%
x = [8.0, 1, 2.5, 4, 28.0]
w = [0.1, 0.2, 0.3, 0.25, 0.15]
wmean = sum(w[i] * x[i] for i in range(len(x))) / sum(w)
wmean

wmean = sum(x_ * w_ for (x_, w_) in zip(x, w)) / sum(w)
wmean
# Out:
# 6.95

# %%
y, z, w = np.array(x), pd.Series(x), np.array(w)
wmean = np.average(y, weights=w)
wmean

wmean = np.average(z, weights=w)
wmean
# Out:
# 6.95

# %%
(w * y).sum() / w.sum()
# Out:
# 6.95

# %%
w = np.array([0.1, 0.2, 0.3, 0.0, 0.2, 0.1])
(w * y_with_nan).sum() / w.sum()

np.average(y_with_nan, weights=w)

np.average(z_with_nan, weights=w)
# Out:
# nan

# %%
hmean = len(x) / sum(1 / item for item in x)
hmean
# Out:
# 2.7613412228796843

# %%
hmean = statistics.harmonic_mean(x)
hmean
# Out:
# 2.7613412228796843

# %%
statistics.harmonic_mean(x_with_nan)

statistics.harmonic_mean([1, 0, 2])

statistics.harmonic_mean([1, 2, -2])  # Raises StatisticsError
# Out:
# ---------------------------------------------------------------------------
# StatisticsError                           Traceback (most recent call last)
# <ipython-input-26-fd37f071cf41> in <module>()
#       3 statistics.harmonic_mean([1, 0, 2])
#       4
# ----> 5 statistics.harmonic_mean([1, 2, -2])  # Raises StatisticsError
#
# /usr/lib/python3.6/statistics.py in harmonic_mean(data)
#     354             raise TypeError('unsupported type')
#     355     try:
# --> 356         T, total, count = _sum(1/x for x in _fail_neg(data, errmsg))
#     357     except ZeroDivisionError:
#     358         return 0
#
# /usr/lib/python3.6/statistics.py in _sum(data, start)
#     146     for typ, values in groupby(data, type):
#     147         T = _coerce(T, typ)  # or raise TypeError
# --> 148         for n,d in map(_exact_ratio, values):
#     149             count += 1
#     150             partials[d] = partials_get(d, 0) + n
#
# /usr/lib/python3.6/statistics.py in <genexpr>(.0)
#     354             raise TypeError('unsupported type')
#     355     try:
# --> 356         T, total, count = _sum(1/x for x in _fail_neg(data, errmsg))
#     357     except ZeroDivisionError:
#     358         return 0
#
# /usr/lib/python3.6/statistics.py in _fail_neg(values, errmsg)
#     283     for x in values:
#     284         if x < 0:
# --> 285             raise StatisticsError(errmsg)
#     286         yield x
#     287
#
# StatisticsError: harmonic mean does not support negative values

# %%
scipy.stats.hmean(y)

scipy.stats.hmean(z)
# Out:
# 2.7613412228796843

# %%
gmean = 1
for item in x:
    gmean *= item

gmean **= 1 / len(x)
gmean
# Out:
# 4.677885674856041

# %%
gmean = statistics.geometric_mean(x)
gmean
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-3fc252cfe1c6> in <module>()
# ----> 1 gmean = statistics.geometric_mean(x)
#       2 gmean
#
# AttributeError: module 'statistics' has no attribute 'geometric_mean'

# %%
gmean = statistics.geometric_mean(x_with_nan)
gmean
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-57ddca06cd92> in <module>()
# ----> 1 gmean = statistics.geometric_mean(x_with_nan)
#       2 gmean
#
# AttributeError: module 'statistics' has no attribute 'geometric_mean'

# %%
scipy.stats.gmean(y)

scipy.stats.gmean(z)
# Out:
# 4.67788567485604

# %%
n = len(x)
if n % 2:
    median_ = sorted(x)[round(0.5*(n-1))]
else:
    x_ord, index = sorted(x), round(0.5 * n)
    median_ = 0.5 * (x_ord[index-1] + x_ord[index])

median_
# Out:
# 4

# %%
median_ = statistics.median(x)
median_

median_ = statistics.median(x[:-1])
median_
# Out:
# 3.25

# %%
statistics.median_low(x[:-1])

statistics.median_high(x[:-1])
# Out:
# 4

# %%
statistics.median(x_with_nan)

statistics.median_low(x_with_nan)

statistics.median_high(x_with_nan)
# Out:
# 8.0

# %%
median_ = np.median(y)
median_

median_ = np.median(y[:-1])
median_
# Out:
# 3.25

# %%
np.nanmedian(y_with_nan)

np.nanmedian(y_with_nan[:-1])
# Out:
# 3.25

# %%
z.median()

z_with_nan.median()
# Out:
# 4.0

# %%
u = [2, 3, 2, 8, 12]
mode_ = max((u.count(item), item) for item in set(u))[1]
mode_
# Out:
# 2

# %%
mode_ = statistics.mode(u)
mode_
mode_ = statistics.multimode(u)
mode_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-b6de118e4fd3> in <module>()
#       1 mode_ = statistics.mode(u)
#       2 mode_
# ----> 3 mode_ = statistics.multimode(u)
#       4 mode_
#
# AttributeError: module 'statistics' has no attribute 'multimode'

# %%
v = [12, 15, 12, 15, 21, 15, 12]
statistics.mode(v)  # Raises StatisticsError
statistics.multimode(v)
# Out:
# ---------------------------------------------------------------------------
# StatisticsError                           Traceback (most recent call last)
# <ipython-input-41-f9f4df717b5d> in <module>()
#       1 v = [12, 15, 12, 15, 21, 15, 12]
# ----> 2 statistics.mode(v)  # Raises StatisticsError
#       3 statistics.multimode(v)
#
# /usr/lib/python3.6/statistics.py in mode(data)
#     505     elif table:
#     506         raise StatisticsError(
# --> 507                 'no unique mode; found %d equally common values' % len(table)
#     508                 )
#     509     else:
#
# StatisticsError: no unique mode; found 2 equally common values

# %%
statistics.mode([2, math.nan, 2])

statistics.multimode([2, math.nan, 2])

statistics.mode([2, math.nan, 0, math.nan, 5])

statistics.multimode([2, math.nan, 0, math.nan, 5])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-659c9760bd8a> in <module>()
#       1 statistics.mode([2, math.nan, 2])
#       2
# ----> 3 statistics.multimode([2, math.nan, 2])
#       4
#       5 statistics.mode([2, math.nan, 0, math.nan, 5])
#
# AttributeError: module 'statistics' has no attribute 'multimode'
