# %% [markdown]
# 1: Đọc dữ liệu
# a) Đầu tiên ta upload file hoặc gán link file vào lệnh Read()
# Sử dụng phương thức read(size) để lấy về dữ liệu có kích thước bằng size. Nếu để trống tham số này thì nó sẽ đọc hết file hoặc nếu file quá lớn thì nó sẽ đọc đến khi giới hạn của bộ nhớ cho phép.
#
# Đọc file ở local host, ở 1 driver khác
#
# upload file lên colab.
#
# from google.colab import files
#
# uploaded = files.upload()
# b) Đọc file từ google drive
#
#   from google.colab import drive
#
#   drive.mount('/content/drive')
#
# - Đọc data
#   	train_df = pd.read_csv(‘URL’)
#
#   	test_df = pd.read_csv(‘URL’)

# %% [markdown]
# 2. Xử lý missing
#
# Đầu tiên chúng ta sử dụng lệnh data.isnull().sum() để xem dữ liệu bị missing
#
# Sau đó tính phần trăm missing của dữ liệu để có thể thay thế bằng mean hoặc median còn nếu găp dữ liệu phân loại thì chọn dữ liệu xuất hiện nhiều nhất  để thay thế các dữ liệu missing bằng hàm fillna()
#
# Nếu thiếu quá nhiều hoặc dữ liệu không thể thay thế(thay thế sẽ làm thay đổi kết quả phân tích) chúng ta dùng hàm drop() để xóa

# %% [markdown]
# 3. summary dữ liệu dùng các đại lượng thống kê mô tả
# chúng ta sẽ sử dụng lệnh Describe () để xem các só liệu thống kê
#
# Count: là dữ liệu mẫu hoặc dữ liệu tổng
#
# Mean là trung bình
#
# Std là độ lệnh chuẩn là độ tương đối của điểm trên đồ thị. Biết được độ phân tán của các giá trị so với giá trị trung bình trong tập dữ liệu, độ lệch chuẩn càng lớn thì dữ liệu càng bị phân tán và ngược lại
#
# Min: điểm nhỏ nhất
#
# 25% và 75%: Là tứ  vị ví dụ vị lớp 100 người bạn đứng 10 thì bạn hơn 89 người
# khác là bạn hơn 89%
#
# 50%:là trung vị của dữ liệu
#
# dữ liệu được chia làm 4 phần bằng nhau 25% để có thể dễ dàng tập trung phân tích vào các khoản dữ liệu mà mình muốn phân tích
#
# Max là điểm cao nhất
#
# các điểm người Min và Max là outlier

# %% [markdown]
# 4. trực quan dữ liệu
# định lượng thì ta dùng biểu đồ histogram
#
# Histogram là biểu đồ áp dụng trên một biến liên tục nhằm tìm ra phân phối tần suất trong những khoảng giá trị được xác định trước của một biến.
# Có 2 cách tạo biểu đồ histogram theo các khoảng giá trị đó là:
#
# •	Phân chia các khoảng giá trị có độ dài bằng nhau và độ dài được tính toán từ số lượng bins khai báo.
#
# •	Tự định nghĩa các khoảng giá trị dựa trên bins_edge là các đầu mút của khoảng.
# Plt.hist() dùng hàm này để vẽ biễu đồ histogram trong python
#
# •	Value distribution (histogram): Cho biết cách các giá trị trong cột của bạn được phân phối. Thanh càng cao, càng nhiều giá trị rơi vào một phạm vi.
#
# •	Min & Max: cho ra các giá trị min,max.
#
# •	Mean: thể hiện giá trị trung bình.
#
# •	Median: thể hiện các giá trị trung vị.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Biểu đồ column hoặc biểu đồ bar để thể hiện các biến phân loại
# Sử dụng Countplot() dùng để biểu diễn các biến phân loại theo 2 trục là trục tung và trục hoành
# Sử dụng hàm  sns.countplot() để vẽ biểu diễn biến phân loại

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# để chỉ ra các giá trị của một số biến định lượng trên các cấp của một biến phân loại là sử dụng stripplot(), nó sẽ vẽ ra một scatterplot cho trường hợp một trong các biến là biến phân loại

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  hàm swarmplot(), đặt vị trí mỗi điểm scatterplot trên trục biểu diễn biến kiểu phân loại với một thuật toán để tránh các điểm chồng chéo nhau

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Sự tương quan giữa 2 biến định lượng:
# Sử dụng scatterplot() để biển diễn sự quan hệ giữa 2 biến định lượng

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Sự tương quan giữa 2 biến định lượng và biến phân loại
# Sử dụng boxplot() để biểu diễn sự tương quan giữa 2 biến định lượng và phân loại
#
# Ở boxplot() biểu đồ diễn tả 5 vị trí phân bố của dữ liệu, đó là: giá trị nhỏ nhất (min), tứ phân vị thứ nhất (Q1), trung vị (median), tứ phân vị thứ 3 (Q3) và giá trị lớn nhất (max).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
